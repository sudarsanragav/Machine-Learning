# %% [markdown]
# <a href="https://colab.research.google.com/github/sudarsanragav/Machine-Learning/blob/sudarsanragav-DeepLearning-1/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_moons
from sklearn import datasets
iris = datasets.load_iris()
from sklearn.metrics import classification_report
import sklearn.model_selection as ms
import numpy as np
from math import exp
from random import random
from matplotlib import pyplot as plt
np.random.seed(111)
from tensorflow.keras import models as km
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import joblib, os
from sklearn.neural_network import MLPClassifier
cpath = os.path.abspath(os.getcwd())
models_path = cpath+"/models"
X, y = make_moons(300, noise=0.20)
#X = iris.data, y = iris.target

# Initialize a network
def initialize_network(n_inputs, n_hidden, n_outputs):
	network = list()
	hidden_layer = [{'weights':[random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
	network.append(hidden_layer)
	output_layer = [{'weights':[random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
	network.append(output_layer)
	return network

# Calculate neuron activation for an input
def activate(weights, inputs):
	activation = weights[-1]
	for i in range(len(weights)-1):
		activation += weights[i] * inputs[i]
	return activation

# Transfer neuron activation
def sigmoid(x):
	return 1.0 / (1.0 + np.exp(-x))

def softmax(y):
    exp_scores = np.exp(y)
    y_hat = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return y_hat

# Forward propagate input to a network output
def forward_propagate(network, row):
    inputs = row
    nn_len = len(network)
    for i in range(nn_len):
        layer = network[i]
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
#            print("activated--->",activation)
            neuron['output'] = sigmoid(activation)
            new_inputs.append(neuron['output'])
        inputs = new_inputs
    y_hat = np.array(inputs)
    return y_hat, network

# Calculate the derivative of an neuron output
def transfer_derivative(output):
	return output * (1.0 - output)

# Backpropagate error and store in neurons
def backward_propagate_error(network, expected):
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = list()
        if i != len(network)-1:
            for j in range(len(layer)):
                error = 0.0
                for neuron in network[i + 1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error)
        else:
            for j in range(len(layer)):
                neuron = layer[j]
                errors.append(expected[j] - neuron['output'])
        
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])
    
    return network


# Update network weights with error
def update_weights(network, x, l_rate):
    for i in range(len(network)):
        inputs = x
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j]
            neuron['weights'][-1] += l_rate * neuron['delta']
    return network


# Train a network for a fixed number of epochs
def train_network(network, x, y, l_rate, n_epoch, n_outputs):
    error_movement=[]
    for epoch in range(n_epoch):
        sum_error = 0
        for i in range(len(x)):
            y_hat, network = forward_propagate(network, x[i])
            expected = [0 for i in range(n_outputs)]
            expected[y[i]] = 1
#            print("y vs y_hat---->",expected, "vs", y_hat)
            sum_error += (1-y_hat[y[i]])**2
#            sum_error += (expected-y_hat)**2
            network = backward_propagate_error(network, expected)
            network = update_weights(network, x[i], l_rate)
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
        error_movement.append(sum_error)
    return network, error_movement


# Make a prediction with a network
def predict(network, data):
    preds=[]
    for row in data:
        y_hat, network = forward_propagate(network, row)
        binary_y_hat = np.argmax(y_hat); #print(binary_y_hat)
        preds.append(binary_y_hat)
#    print(preds)
    return preds


def print_nn(network):
    print("Network Layers:")
    l=0
    for layer in network:
        l=l+1
        if l==1: print("Hidden Layers:")
        if l==2: print("Output Layer:")
        for neuron in layer:
            print(neuron)
        print("")


def view_cr(y_train,y_test,train_pred,test_pred):
    print("Training:")
    print(classification_report(y_train, train_pred))
#    print("roc_auc:", roc_auc_score(y_train, train_pred))
    print("")
#    print("% of Unknown classe @ threshold = "+str(pred_th), " is ", round(len(test_pred[test_pred==-1])/len(test_pred),3))
    print("Testing:")
    print(classification_report(y_test, test_pred))
        

def ann_train_test(X,y,lib,model_name):
    model_file = models_path+"/"+model_name+"_ann_"+lib+".pkl"
    x_train,x_test,y_train,y_test=ms.train_test_split(X,y,test_size=0.2, random_state=111)
    n_inputs = len(x_train[0])
    n_outputs = len(set(list(y))); print("classes--->",n_outputs)
    n_epoch = 500
    
    if lib == 'custom':
        n_hidden = 3
        l_rate = 0.5
        network = initialize_network(n_inputs, n_hidden, n_outputs)
        network, em = train_network(network, x_train, y_train, l_rate, n_epoch, n_outputs)
        print_nn(network)
        plt.plot(em); plt.show()
        joblib.dump(network, model_file)
        network = joblib.load(model_file)
        train_pred = predict(network, x_train)
        test_pred = predict(network, x_test)
        view_cr(y_train,y_test,train_pred,test_pred)



    if lib == 'mlp':
        model = MLPClassifier()
        print(model)
        model.fit(x_train,y_train)
        joblib.dump(model,model_file)
        model = joblib.load(model_file)
        train_pred = model.predict(x_train)
        test_pred = model.predict(x_test)
        view_cr(y_train, y_test, train_pred, test_pred)



    if lib == 'keras':
#        y_train = np.asarray(y_train).astype('float32').reshape((-1,1))
#        y_test = np.asarray(y_test).astype('float32').reshape((-1,1))
        if n_outputs == 2:
            loss_fuction = 'binary_crossentropy'
            last_activation = 'sigmoid'
        elif n_outputs > 2:
            loss_fuction = 'categorical_crossentropy'
            last_activation = 'softmax'
        model = Sequential()
        model.add(Dense(12, input_dim=n_inputs, activation='relu'))
        model.add(Dense(8, activation='sigmoid'))
        model.add(Dense(1, activation=last_activation))
        opt = Adam(learning_rate=0.01)
        model.compile(loss=loss_fuction, optimizer=opt, metrics=['accuracy'])
        model.fit(x_train, y_train, epochs=n_epoch, batch_size=10, shuffle=False)
        model.save(model_file)
        model = km.load_model(model_file)


        if n_outputs == 2:
            train_pred = (model.predict(x_train) > 0.5).astype("int32")
            test_pred = (model.predict(x_test) > 0.5).astype("int32")
        elif n_outputs > 2:
            train_pred = np.argmax(model.predict(x_train), axis=-1)
            test_pred = np.argmax(model.predict(x_test), axis=-1)


        print(y_train[:5]); print(train_pred[:5])
        view_cr(y_train,y_test,train_pred,test_pred)

models_path = "../models"
ann_train_test(X,y,'keras','makemoon')
#MLP = 87%, custom ANN = 90%, keras DNN = 98%
ann.py
# Out:
# classes---> 2
# Epoch 1/500
# 24/24 [==============================] - 1s 3ms/step - loss: 0.6153 - accuracy: 0.7417
# Epoch 2/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4481 - accuracy: 0.8375
# Epoch 3/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3348 - accuracy: 0.8667
# Epoch 4/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2913 - accuracy: 0.8875
# Epoch 5/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2726 - accuracy: 0.8792
# Epoch 6/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2612 - accuracy: 0.8792
# Epoch 7/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.8750
# Epoch 8/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2440 - accuracy: 0.8792
# Epoch 9/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2357 - accuracy: 0.8833
# Epoch 10/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2273 - accuracy: 0.8875
# Epoch 11/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2171 - accuracy: 0.8958
# Epoch 12/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2082 - accuracy: 0.9042
# Epoch 13/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1962 - accuracy: 0.9208
# Epoch 14/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1849 - accuracy: 0.9292
# Epoch 15/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1738 - accuracy: 0.9292
# Epoch 16/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1606 - accuracy: 0.9375
# Epoch 17/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1492 - accuracy: 0.9458
# Epoch 18/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1393 - accuracy: 0.9458
# Epoch 19/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1293 - accuracy: 0.9458
# Epoch 20/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1194 - accuracy: 0.9667
# Epoch 21/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1132 - accuracy: 0.9667
# Epoch 22/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9667
# Epoch 23/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1004 - accuracy: 0.9667
# Epoch 24/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0952 - accuracy: 0.9667
# Epoch 25/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9708
# Epoch 26/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0861 - accuracy: 0.9708
# Epoch 27/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0833 - accuracy: 0.9750
# Epoch 28/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.9792
# Epoch 29/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9792
# Epoch 30/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9792
# Epoch 31/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0719 - accuracy: 0.9750
# Epoch 32/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0690 - accuracy: 0.9792
# Epoch 33/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9792
# Epoch 34/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9792
# Epoch 35/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9792
# Epoch 36/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0617 - accuracy: 0.9833
# Epoch 37/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9833
# Epoch 38/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9833
# Epoch 39/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0585 - accuracy: 0.9833
# Epoch 40/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0569 - accuracy: 0.9833
# Epoch 41/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0558 - accuracy: 0.9833
# Epoch 42/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.9833
# Epoch 43/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 0.9833
# Epoch 44/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0538 - accuracy: 0.9833
# Epoch 45/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0527 - accuracy: 0.9833
# Epoch 46/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0520 - accuracy: 0.9833
# Epoch 47/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0513 - accuracy: 0.9833
# Epoch 48/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0516 - accuracy: 0.9833
# Epoch 49/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9833
# Epoch 50/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0493 - accuracy: 0.9833
# Epoch 51/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0488 - accuracy: 0.9833
# Epoch 52/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0486 - accuracy: 0.9833
# Epoch 53/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 0.9833
# Epoch 54/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 0.9833
# Epoch 55/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 0.9833
# Epoch 56/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 0.9833
# Epoch 57/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 0.9833
# Epoch 58/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0470 - accuracy: 0.9833
# Epoch 59/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0464 - accuracy: 0.9833
# Epoch 60/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0463 - accuracy: 0.9833
# Epoch 61/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0458 - accuracy: 0.9833
# Epoch 62/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9833
# Epoch 63/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 0.9833
# Epoch 64/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0456 - accuracy: 0.9833
# Epoch 65/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 0.9833
# Epoch 66/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0453 - accuracy: 0.9833
# Epoch 67/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9833
# Epoch 68/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0449 - accuracy: 0.9833
# Epoch 69/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0444 - accuracy: 0.9833
# Epoch 70/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9833
# Epoch 71/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 0.9833
# Epoch 72/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0446 - accuracy: 0.9833
# Epoch 73/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0441 - accuracy: 0.9833
# Epoch 74/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 0.9833
# Epoch 75/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 0.9833
# Epoch 76/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0440 - accuracy: 0.9833
# Epoch 77/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9833
# Epoch 78/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9833
# Epoch 79/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 0.9833
# Epoch 80/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9833
# Epoch 81/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9833
# Epoch 82/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9833
# Epoch 83/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0434 - accuracy: 0.9833
# Epoch 84/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 0.9833
# Epoch 85/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0433 - accuracy: 0.9833
# Epoch 86/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0434 - accuracy: 0.9833
# Epoch 87/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0435 - accuracy: 0.9833
# Epoch 88/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9833
# Epoch 89/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9833
# Epoch 90/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0430 - accuracy: 0.9833
# Epoch 91/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9833
# Epoch 92/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9833
# Epoch 93/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9833
# Epoch 94/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.9833
# Epoch 95/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0434 - accuracy: 0.9833
# Epoch 96/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9833
# Epoch 97/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0433 - accuracy: 0.9833
# Epoch 98/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9833
# Epoch 99/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.9833
# Epoch 100/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9833
# Epoch 101/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0431 - accuracy: 0.9833
# Epoch 102/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.9833
# Epoch 103/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9833
# Epoch 104/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9833
# Epoch 105/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0430 - accuracy: 0.9833
# Epoch 106/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9833
# Epoch 107/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.9833
# Epoch 108/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0423 - accuracy: 0.9833
# Epoch 109/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 0.9833
# Epoch 110/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.9833
# Epoch 111/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9833
# Epoch 112/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0424 - accuracy: 0.9833
# Epoch 113/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9833
# Epoch 114/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0422 - accuracy: 0.9833
# Epoch 115/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0429 - accuracy: 0.9833
# Epoch 116/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9833
# Epoch 117/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9833
# Epoch 118/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0422 - accuracy: 0.9833
# Epoch 119/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0428 - accuracy: 0.9833
# Epoch 120/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.9833
# Epoch 121/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0428 - accuracy: 0.9833
# Epoch 122/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9833
# Epoch 123/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.9833
# Epoch 124/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9833
# Epoch 125/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.9833
# Epoch 126/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.9833
# Epoch 127/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9833
# Epoch 128/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 129/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0425 - accuracy: 0.9833
# Epoch 130/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.9833
# Epoch 131/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9833
# Epoch 132/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 133/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9833
# Epoch 134/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9833
# Epoch 135/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9833
# Epoch 136/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 137/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.9833
# Epoch 138/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9833
# Epoch 139/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9833
# Epoch 140/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9833
# Epoch 141/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9833
# Epoch 142/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 143/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9833
# Epoch 144/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.9833
# Epoch 145/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 146/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 147/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9833
# Epoch 148/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 149/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 150/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 0.9833
# Epoch 151/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 152/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 153/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0436 - accuracy: 0.9833
# Epoch 154/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 0.9750
# Epoch 155/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0409 - accuracy: 0.9833
# Epoch 156/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0452 - accuracy: 0.9833
# Epoch 157/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9833
# Epoch 158/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9833
# Epoch 159/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9833
# Epoch 160/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9833
# Epoch 161/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0407 - accuracy: 0.9833
# Epoch 162/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 0.9833
# Epoch 163/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0405 - accuracy: 0.9833
# Epoch 164/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0404 - accuracy: 0.9833
# Epoch 165/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0403 - accuracy: 0.9833
# Epoch 166/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0403 - accuracy: 0.9833
# Epoch 167/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 0.9833
# Epoch 168/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 0.9833
# Epoch 169/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0403 - accuracy: 0.9833
# Epoch 170/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9833
# Epoch 171/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 0.9833
# Epoch 172/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9833
# Epoch 173/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9833
# Epoch 174/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0398 - accuracy: 0.9833
# Epoch 175/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9833
# Epoch 176/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9833
# Epoch 177/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9833
# Epoch 178/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0396 - accuracy: 0.9833
# Epoch 179/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 0.9833
# Epoch 180/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 0.9833
# Epoch 181/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 0.9833
# Epoch 182/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0395 - accuracy: 0.9833
# Epoch 183/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 0.9833
# Epoch 184/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 0.9833
# Epoch 185/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0398 - accuracy: 0.9833
# Epoch 186/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0394 - accuracy: 0.9833
# Epoch 187/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0398 - accuracy: 0.9833
# Epoch 188/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 0.9833
# Epoch 189/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 0.9833
# Epoch 190/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9833
# Epoch 191/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9833
# Epoch 192/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0397 - accuracy: 0.9833
# Epoch 193/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0393 - accuracy: 0.9833
# Epoch 194/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 0.9833
# Epoch 195/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0395 - accuracy: 0.9833
# Epoch 196/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 0.9833
# Epoch 197/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0392 - accuracy: 0.9833
# Epoch 198/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 0.9833
# Epoch 199/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9833
# Epoch 200/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0392 - accuracy: 0.9833
# Epoch 201/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 0.9833
# Epoch 202/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 0.9833
# Epoch 203/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0392 - accuracy: 0.9833
# Epoch 204/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9833
# Epoch 205/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9833
# Epoch 206/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9833
# Epoch 207/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 0.9833
# Epoch 208/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9833
# Epoch 209/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9833
# Epoch 210/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9833
# Epoch 211/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9833
# Epoch 212/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 0.9833
# Epoch 213/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9833
# Epoch 214/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9833
# Epoch 215/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9833
# Epoch 216/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9833
# Epoch 217/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0388 - accuracy: 0.9833
# Epoch 218/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 0.9833
# Epoch 219/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9833
# Epoch 220/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9833
# Epoch 221/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 0.9833
# Epoch 222/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0388 - accuracy: 0.9833
# Epoch 223/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0385 - accuracy: 0.9833
# Epoch 224/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9833
# Epoch 225/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9833
# Epoch 226/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0383 - accuracy: 0.9833
# Epoch 227/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9833
# Epoch 228/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 0.9833
# Epoch 229/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0385 - accuracy: 0.9833
# Epoch 230/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0386 - accuracy: 0.9833
# Epoch 231/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0383 - accuracy: 0.9833
# Epoch 232/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 0.9833
# Epoch 233/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 0.9833
# Epoch 234/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 0.9833
# Epoch 235/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0385 - accuracy: 0.9833
# Epoch 236/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0380 - accuracy: 0.9833
# Epoch 237/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0385 - accuracy: 0.9833
# Epoch 238/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9833
# Epoch 239/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9833
# Epoch 240/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0382 - accuracy: 0.9833
# Epoch 241/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9833
# Epoch 242/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9833
# Epoch 243/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9833
# Epoch 244/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 0.9833
# Epoch 245/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9833
# Epoch 246/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0378 - accuracy: 0.9833
# Epoch 247/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 0.9833
# Epoch 248/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9833
# Epoch 249/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0376 - accuracy: 0.9833
# Epoch 250/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9833
# Epoch 251/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9833
# Epoch 252/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 0.9833
# Epoch 253/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0374 - accuracy: 0.9833
# Epoch 254/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 0.9833
# Epoch 255/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9833
# Epoch 256/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9833
# Epoch 257/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9833
# Epoch 258/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9833
# Epoch 259/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9833
# Epoch 260/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0374 - accuracy: 0.9833
# Epoch 261/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0371 - accuracy: 0.9833
# Epoch 262/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0370 - accuracy: 0.9833
# Epoch 263/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 0.9833
# Epoch 264/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0369 - accuracy: 0.9833
# Epoch 265/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9833
# Epoch 266/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9833
# Epoch 267/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9833
# Epoch 268/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9833
# Epoch 269/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.9833
# Epoch 270/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 0.9833
# Epoch 271/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0363 - accuracy: 0.9833
# Epoch 272/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 0.9833
# Epoch 273/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0360 - accuracy: 0.9833
# Epoch 274/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 0.9833
# Epoch 275/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9833
# Epoch 276/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 0.9833
# Epoch 277/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9833
# Epoch 278/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9833
# Epoch 279/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9833
# Epoch 280/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0353 - accuracy: 0.9833
# Epoch 281/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9833
# Epoch 282/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9833
# Epoch 283/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0353 - accuracy: 0.9833
# Epoch 284/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9833
# Epoch 285/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9833
# Epoch 286/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 0.9833
# Epoch 287/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 0.9833
# Epoch 288/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9833
# Epoch 289/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 0.9833
# Epoch 290/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 0.9833
# Epoch 291/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 0.9833
# Epoch 292/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 0.9833
# Epoch 293/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9833
# Epoch 294/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9833
# Epoch 295/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0343 - accuracy: 0.9833
# Epoch 296/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 0.9833
# Epoch 297/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9833
# Epoch 298/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0343 - accuracy: 0.9833
# Epoch 299/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9833
# Epoch 300/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9833
# Epoch 301/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9833
# Epoch 302/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0338 - accuracy: 0.9833
# Epoch 303/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0335 - accuracy: 0.9833
# Epoch 304/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0337 - accuracy: 0.9833
# Epoch 305/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 0.9833
# Epoch 306/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9833
# Epoch 307/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9833
# Epoch 308/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 0.9833
# Epoch 309/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 0.9833
# Epoch 310/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0333 - accuracy: 0.9833
# Epoch 311/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9833
# Epoch 312/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9833
# Epoch 313/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 0.9833
# Epoch 314/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0331 - accuracy: 0.9833
# Epoch 315/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 0.9833
# Epoch 316/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9833
# Epoch 317/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 0.9833
# Epoch 318/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0325 - accuracy: 0.9833
# Epoch 319/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 0.9833
# Epoch 320/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9833
# Epoch 321/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 0.9833
# Epoch 322/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0322 - accuracy: 0.9833
# Epoch 323/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9833
# Epoch 324/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9833
# Epoch 325/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 0.9833
# Epoch 326/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0323 - accuracy: 0.9833
# Epoch 327/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 0.9833
# Epoch 328/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 0.9833
# Epoch 329/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 0.9833
# Epoch 330/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0319 - accuracy: 0.9833
# Epoch 331/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0319 - accuracy: 0.9833
# Epoch 332/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 0.9833
# Epoch 333/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0318 - accuracy: 0.9833
# Epoch 334/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0318 - accuracy: 0.9833
# Epoch 335/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9833
# Epoch 336/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0319 - accuracy: 0.9833
# Epoch 337/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 0.9833
# Epoch 338/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9833
# Epoch 339/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9833
# Epoch 340/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9833
# Epoch 341/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9833
# Epoch 342/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0318 - accuracy: 0.9833
# Epoch 343/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 0.9833
# Epoch 344/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0312 - accuracy: 0.9833
# Epoch 345/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0312 - accuracy: 0.9833
# Epoch 346/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0313 - accuracy: 0.9833
# Epoch 347/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0306 - accuracy: 0.9833
# Epoch 348/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9833
# Epoch 349/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9833
# Epoch 350/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9833
# Epoch 351/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0305 - accuracy: 0.9833
# Epoch 352/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0312 - accuracy: 0.9833
# Epoch 353/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9833
# Epoch 354/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9833
# Epoch 355/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9833
# Epoch 356/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 0.9833
# Epoch 357/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0305 - accuracy: 0.9833
# Epoch 358/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0306 - accuracy: 0.9833
# Epoch 359/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 0.9833
# Epoch 360/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 0.9833
# Epoch 361/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9833
# Epoch 362/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0300 - accuracy: 0.9833
# Epoch 363/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9833
# Epoch 364/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0302 - accuracy: 0.9833
# Epoch 365/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9833
# Epoch 366/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 0.9833
# Epoch 367/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 0.9833
# Epoch 368/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0296 - accuracy: 0.9833
# Epoch 369/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 0.9833
# Epoch 370/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9833
# Epoch 371/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9833
# Epoch 372/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 0.9833
# Epoch 373/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 0.9833
# Epoch 374/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9833
# Epoch 375/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9833
# Epoch 376/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 0.9833
# Epoch 377/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 0.9833
# Epoch 378/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9833
# Epoch 379/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 0.9833
# Epoch 380/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 0.9833
# Epoch 381/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0286 - accuracy: 0.9833
# Epoch 382/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9833
# Epoch 383/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9833
# Epoch 384/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 0.9833
# Epoch 385/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 0.9833
# Epoch 386/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0277 - accuracy: 0.9833
# Epoch 387/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0278 - accuracy: 0.9833
# Epoch 388/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 0.9833
# Epoch 389/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0277 - accuracy: 0.9833
# Epoch 390/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 0.9833
# Epoch 391/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0277 - accuracy: 0.9833
# Epoch 392/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 0.9833
# Epoch 393/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9833
# Epoch 394/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9833
# Epoch 395/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9833
# Epoch 396/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9833
# Epoch 397/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9833
# Epoch 398/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9833
# Epoch 399/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9833
# Epoch 400/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9833
# Epoch 401/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9833
# Epoch 402/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9833
# Epoch 403/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9833
# Epoch 404/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9833
# Epoch 405/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9833
# Epoch 406/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9833
# Epoch 407/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9833
# Epoch 408/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9833
# Epoch 409/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.9833
# Epoch 410/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9833
# Epoch 411/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9833
# Epoch 412/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 0.9833
# Epoch 413/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9833
# Epoch 414/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9833
# Epoch 415/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 0.9833
# Epoch 416/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9833
# Epoch 417/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9833
# Epoch 418/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9833
# Epoch 419/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9833
# Epoch 420/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 0.9833
# Epoch 421/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9833
# Epoch 422/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 0.9833
# Epoch 423/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9833
# Epoch 424/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9875
# Epoch 425/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 0.9833
# Epoch 426/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9833
# Epoch 427/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9833
# Epoch 428/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9833
# Epoch 429/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0246 - accuracy: 0.9833
# Epoch 430/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9875
# Epoch 431/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9833
# Epoch 432/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9833
# Epoch 433/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 0.9875
# Epoch 434/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9833
# Epoch 435/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9833
# Epoch 436/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0244 - accuracy: 0.9875
# Epoch 437/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9875
# Epoch 438/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 0.9875
# Epoch 439/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9833
# Epoch 440/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9875
# Epoch 441/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9833
# Epoch 442/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9875
# Epoch 443/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 0.9875
# Epoch 444/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9875
# Epoch 445/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9875
# Epoch 446/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0232 - accuracy: 0.9875
# Epoch 447/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0235 - accuracy: 0.9875
# Epoch 448/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9875
# Epoch 449/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9875
# Epoch 450/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 0.9875
# Epoch 451/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9875
# Epoch 452/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9875
# Epoch 453/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9875
# Epoch 454/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9875
# Epoch 455/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 0.9875
# Epoch 456/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 0.9875
# Epoch 457/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9875
# Epoch 458/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9875
# Epoch 459/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9875
# Epoch 460/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9875
# Epoch 461/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.9875
# Epoch 462/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9875
# Epoch 463/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9875
# Epoch 464/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9875
# Epoch 465/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9875
# Epoch 466/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9875
# Epoch 467/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 0.9875
# Epoch 468/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9875
# Epoch 469/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9875
# Epoch 470/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9875
# Epoch 471/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.9875
# Epoch 472/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9875
# Epoch 473/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9875
# Epoch 474/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9875
# Epoch 475/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.9875
# Epoch 476/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 0.9875
# Epoch 477/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9875
# Epoch 478/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9708
# Epoch 479/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9750
# Epoch 480/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9875
# Epoch 481/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 0.9875
# Epoch 482/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 0.9917
# Epoch 483/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9875
# Epoch 484/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9875
# Epoch 485/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 0.9875
# Epoch 486/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9875
# Epoch 487/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9875
# Epoch 488/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 0.9875
# Epoch 489/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9875
# Epoch 490/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9875
# Epoch 491/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9875
# Epoch 492/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 0.9875
# Epoch 493/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9875
# Epoch 494/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9875
# Epoch 495/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9875
# Epoch 496/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9875
# Epoch 497/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9875
# Epoch 498/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9875
# Epoch 499/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9875
# Epoch 500/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9875
# INFO:tensorflow:Assets written to: ../models/makemoon_ann_keras.pkl/assets
# [0 1 0 0 1]
# [[0]
#  [1]
#  [0]
#  [0]
#  [1]]
# Training:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       118
#            1       0.98      0.99      0.99       122
#
#     accuracy                           0.99       240
#    macro avg       0.99      0.99      0.99       240
# weighted avg       0.99      0.99      0.99       240
#
#
# Testing:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        32
#            1       0.96      0.96      0.96        28
#
#     accuracy                           0.97        60
#    macro avg       0.97      0.97      0.97        60
# weighted avg       0.97      0.97      0.97        60
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4943de3fa38a> in <module>()
#     221 ann_train_test(X,y,'keras','makemoon')
#     222 #MLP = 87%, custom ANN = 90%, keras DNN = 98%
# --> 223 ann.py
#
# NameError: name 'ann' is not defined
